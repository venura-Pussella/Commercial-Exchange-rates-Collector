# %%
import pandas as pd 

df = pd.read_html("file.html")[15]

df
# Out:
#           Exchange Rates                        \
#           Exchange Rates
#           Exchange Rates      Exchange Rates.1
# 0             US DOLLARS            US DOLLARS
# 1                   EURO                  EURO
# 2        STERLING POUNDS       STERLING POUNDS
# 3           JAPANESE YEN          JAPANESE YEN
# 4      SINGAPORE DOLLARS     SINGAPORE DOLLARS
# 5     AUSTRALIAN DOLLARS    AUSTRALIAN DOLLARS
# 6           SWISS FRANCS          SWISS FRANCS
# 7         KUWAITI DINARS        KUWAITI DINARS
# 8           OMANI RIYALS          OMANI RIYALS
# 9   SAUDI ARABIAN RIYALS  SAUDI ARABIAN RIYALS
# 10           UAE DIRHAMS           UAE DIRHAMS
# 11          QATAR RIYALS          QATAR RIYALS
# 12      JORDANIAN DINARS      JORDANIAN DINARS
# 13        BAHRAIN DINARS        BAHRAIN DINARS
# 14         INDIAN RUPEES         INDIAN RUPEES
# 15       CANADIAN DOLLAR       CANADIAN DOLLAR
# 16   NEW ZEALAND DOLLARS   NEW ZEALAND DOLLARS
#
# ...

# %%
count = len(df)

print(count)
# Out:
# 52
